# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishnaviii21/Week-1/blob/main/Week07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image 
import numpy as np 
img = Image.open("/content/pic 1.jpg")
print(type(img))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
print(img.format)
# Out:
# JPEG

# %%
print(img.mode) 
img1 = np.asarray(img)
print(type(img1))
# Out:
# RGB
# <class 'numpy.ndarray'>

# %%
img1
# Out:
# array([[[161, 190, 185],
#         [160, 191, 185],
#         [160, 191, 185],
#         ...,
#         [ 63, 124, 168],
#         [ 61, 122, 166],
#         [ 60, 121, 165]],
#
#        [[162, 191, 186],
#         [161, 192, 186],
#         [160, 191, 185],
#         ...,
#         [ 62, 123, 167],
#         [ 61, 122, 166],
#         [ 60, 121, 165]],
#
#        [[162, 191, 186],
#         [161, 192, 186],
#         [161, 192, 186],
#         ...,
#         [ 64, 123, 167],
#         [ 61, 122, 166],
#         [ 61, 122, 166]],
#
#        ...,
#
#        [[ 75,  68,   0],
#         [ 73,  70,   0],
#         [ 72,  73,   3],
#         ...,
#         [ 65,  72,   4],
#         [ 66,  73,   6],
#         [ 59,  68,   5]],
#
#        [[ 86,  71,   2],
#         [ 81,  73,   0],
#         [ 75,  76,   0],
#         ...,
#         [ 69,  74,   8],
#         [ 64,  70,   6],
#         [ 58,  64,   4]],
#
#        [[ 96,  78,   6],
#         [ 88,  80,   0],
#         [ 80,  84,   0],
# ...

# %%
img1.shape
# Out:
# (327, 528, 3)

# %%
print(img1.shape)
# Out:
# (327, 528, 3)

# %%
img = Image.open("/content/pic 1.jpg") 
print(type(img))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
img2 = Image.open("/content/pic 2.jpg")
print(type(img2))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
img2.shape

# %%
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 

img = mpimg.imread("/content/pic 1.jpg")  
print(type(img))

print(img.shape)

plt.imshow(img)
plt.colorbar()
# Out:
# <class 'numpy.ndarray'>
# (327, 528, 3)

# %%
from skimage import io, img_as_float, img_as_ubyte
import numpy as np
import matplotlib.pyplot as plt 


image = img_as_float(io.imread("/content/pic 1.jpg"))

image2 = io.imread("/content/pic 2.jpg").astype(np.float)
print(image2)
# Out:
# [[[ 35.  53.  77.]
#   [ 34.  52.  76.]
#   [ 34.  52.  76.]
#   ...
#   [  0.   2.   9.]
#   [ 55.  56.  61.]
#   [155. 156. 161.]]
#
#  [[ 35.  53.  77.]
#   [ 34.  52.  76.]
#   [ 34.  52.  76.]
#   ...
#   [  7.  10.  17.]
#   [  0.   0.   5.]
#   [ 16.  17.  22.]]
#
#  [[ 35.  53.  77.]
#   [ 34.  52.  76.]
#   [ 34.  52.  76.]
#   ...
#   [  7.  10.  17.]
#   [  0.   0.   5.]
#   [  1.   2.   7.]]
#
#  ...
#
#  [[ 68.  75.  94.]
#   [ 67.  74.  93.]
#   [ 66.  74.  93.]
#   ...
#   [ 68.  74.  88.]
#   [ 67.  73.  87.]
#   [ 69.  75.  89.]]
#
#  [[ 68.  75.  94.]
#   [ 67.  74.  93.]
#   [ 66.  74.  93.]
#   ...
#   [ 68.  74.  88.]
#   [ 67.  73.  87.]
#   [ 69.  75.  89.]]
#
#  [[ 68.  75.  94.]
#   [ 67.  74.  93.]
#   [ 66.  74.  93.]
#   ...
#   [ 68.  74.  88.]
#   [ 67.  73.  87.]
#   [ 69.  75.  89.]]]
# ...

# %%
import cv2  # library for Open Source Computer vision library

from google.colab.patches import cv2_imshow

grey_img = cv2.imread("/content/pic 2.jpg", 0)
color_img = cv2.imread("/content/pic 1.jpg", 1)

print(type(grey_img)) 
print(type(color_img))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
cv2_imshow(grey_img)
cv2_imshow(color_img)
# Out:
# <PIL.Image.Image image mode=L size=2000x1331 at 0x7F79064D7050>
# <PIL.Image.Image image mode=RGB size=528x327 at 0x7F79130D04D0>

# %%
plt.imshow(cv2.cvtColor(color_img, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(color_img, cv2.COLOR_BGR2HSV))

# %%
import numpy as np       
import matplotlib.pylab as plt  
from io import BytesIO
import cv2  
from PIL import Image  
from google.colab.patches import cv2_imshow
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7c89f7d6-a97b-47dc-94bb-f12e84f42fed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c89f7d6-a97b-47dc-94bb-f12e84f42fed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
